# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.scatter(df['area'], df['price'])
plt.xlabel("Area (sq ft)")
plt.ylabel("Price ($)")
plt.title("Area vs Price")
plt.show()

# %%
corr = df['area'].corr(df['price'])
print("Correlation between area and price:", corr)
# Out:
# Correlation between area and price: 0.5359973457780796
